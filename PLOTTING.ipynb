# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/shri/Documents/codes/practice code files/GarfinkelCardiacData2.csv")
df.head(2)
# Out:
#    Serial No  Basal Heart Rate  Basal Blood Pressure  \
# 0          1              92.0                 103.0
# 1          2              62.0                 139.0
#
#    Basal Double Product BHR*BBP
# 0                        9476.0
# 1                        8618.0

# %%
#HISTOGRAM PLOTTING :-FREQ VS N_VALUES
df.hist()
df.plot()

# %%
#df.plot(kind='box', subplots=True, layout=(3,2), sharex=False, sharey=False)
#plt.show()
plt.figure()
plt.boxplot(df)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(3,2), sharex=False, sharey=False)
plt.show()



#box plotting in one line with respect to one another

# %%
#BASIC PARAMETERS
df.describe()
# Out:
#         Serial No  Basal Heart Rate  Basal Blood Pressure  \
# count  559.000000        558.000000            558.000000
# mean   280.000000         75.290323            135.324373
# std    161.513673         15.415197             20.770106
# min      1.000000         42.000000             85.000000
# 25%    140.500000         64.000000            120.000000
# 50%    280.000000         74.000000            133.000000
# 75%    419.500000         84.000000            150.000000
# max    559.000000        210.000000            203.000000
#
#        Basal Double Product BHR*BBP
# count                    558.000000
# mean                   10181.313620
# std                     2579.749367
# min                     5000.000000
# 25%                     8400.000000
# 50%                     9792.000000
# 75%                    11663.250000
# max                    27300.000000

# %%
#PLOT CUMSUM
df.sort_index().cumsum().plot()

#alternative way to plot cumsum
#You may set the legend argument to False to hide the legend, which is shown by default.

#df = df.cumsum()
#df.plot(legend=False)

#and
#df = df.cumsum()
#df.plot()

# %%
#PLOTTING MULTIPLELINE LINEPLOT

plt.plot( 'Serial No', 'Basal Heart Rate', data=df, marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=1)
plt.plot( 'Serial No', 'Basal Blood Pressure', data=df, marker='', color='olive', linewidth=1)
#plt.plot( 'Serial No', 'Basal Double Product BHR*BBP', data=df, marker='', color='pink', linewidth=1)

# %%
#BOX_PLOTING_FIG:-VALUES

plt.figure()
#plt.boxplot(df, 1)
#plt.figure()
plt.boxplot(df)

plt.show()

# %%
#BAR’ or ‘BARH’ FOR BAR PLOTS
plt.figure();
df.iloc[5].plot(kind='bar');

# %%
#BAR PLOT FOR SIMUL. READINGS IN THAT RANGE
df.plot.bar();

# %%
#BARPLOT IN OPO_CO_ORDINATES
df.plot.barh(stacked=True);

# %%
df.plot.bar(stacked=True);

# %%
#HISTOGRAM PLOTTING _ 


plt.figure();
df.plot.hist(alpha=0.5)

# %%
df.plot.hist(stacked=True, bins=20)

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9d2fef0d68>,
# ...
#       dtype=object)

# %%
#BOX PLOTTING _ IN ONE LINE
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
df.plot.box(color=color, sym='r+')

# %%
#df.plot.area(stacked=False);
df.plot.area();

# %%
#Scatter Matrix Plot 
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9d33643a20>,
# ...
#       dtype=object)

# %%
#Density Plot
df.plot.kde()

# %%
#from pandas.plotting import parallel_coordinates
#plt.figure()
#parallel_coordinates(df, 'Name')



#Lag plots are used to check if a data set or time series is random. 
#Random data should not exhibit any structure in the lag plot. 
from pandas.plotting import lag_plot
plt.figure()
lag_plot(df)

# %%
#Bootstrap plots are used to visually assess the uncertainty of a statistic, 
#such as mean, median, midrange, etc. A random subset of a specified size is selected 
#from a data set, the statistic in question is computed for this subset and the process 
#is repeated a specified number of times. Resulting plots and histograms are 
#what constitutes the bootstrap plot.

# %%
#General plot style arguments
#Most plotting methods have a set of keyword arguments that control the layout and 
#formatting of the returned plot:


plt.figure();
df.plot(style='k--', label='Series');

# %%
df.plot()
#df.plot(secondary_y=True, style='g')

# %%
#Subplots
#Each Series in a DataFrame can be plotted on a different axis with the subplots keyword:
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False);

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(6, 6), sharex=False);

# %%
df = df.cumsum()
plt.figure()
df.plot(colormap='cubehelix')
